# %% [markdown]
# # Choosing a city from CityBikes API

# %%
#importing the required libraries.

import plotly.express as px
import pandas as pd
import numpy as np
import seaborn as sns                       # visualisation
import matplotlib.pyplot as plt             # visualisation
# %matplotlib inline 
sns.set(color_codes=True)
import requests                            # Might be needed:
#import datetime                            # Might be needed
import json
import time
from pprint import pprint
from pathlib import Path 

# https://location.foursquare.com/developer/reference/place-search #url for the foursquare api requests

# %%
save_num_newdf = 1
save_num_df = 1
save_num_ll = 1
save_num_lat = 1
save_num_long = 1
save_num_df_fsq = 1
save_num_df_yelp = 1

# %%
# trial_get = requests.get("https://api.citybik.es/v2/networks").json()
# # trial_get to test for function below

# %%
#define a function to return a list of dictionaries with information about the requested city
def citybikes_locations(city):
    citybike_networks = requests.get("https://api.citybik.es/v2/networks").json()
    list_of_dict = []
    for citybike_dict in citybike_networks['networks']:
        new_city = citybike_dict['location']['city']
        if new_city.lower() == city.lower():
            list_of_dict.append(citybike_dict)
    return list_of_dict

    # reference: https://medium.com/@ajosegun_/real-time-dashboard-in-python-b8c9a9c4e050

# %%
#define a function to return a list of dictionaries about the city's stations
def city_stations(city):
    station_dict = citybikes_locations(city)
    if not station_dict:
        print('Error: No info found for {}'.format(city))
        return None
    network_address = station_dict[0]['href']
    url = "https://api.citybik.es/{}".format(network_address)
    return requests.get(url).json()['network']['stations']

    # reference: https://medium.com/@ajosegun_/real-time-dashboard-in-python-b8c9a9c4e050

# %%
#define a function that will return a pd.df about the stations for input city
def station_data(city):
    station_info = city_stations(city)
    station_list = []
    for info in station_info:
        a_dict = {
            'Station Name': info['name']
            , 'slots': info['extra']['slots']
            , 'empty_slots': info['empty_slots']
            , 'free_bikes': info['free_bikes']
            , 'status': info['extra']['status']
            , 'bank_card': ', '.join(info['extra']['bank_card']) if info['extra']['bank_card'] else 'No'
            , 'latitude': info['latitude']
            , 'longitude': info['longitude']
            , 'timestamp': info['timestamp']
            , 'Unique ID': info['extra']['uid']
        }
        station_list.append(a_dict)
    return pd.DataFrame(station_list)

# %%
jsonFn1_van_network = citybikes_locations("Vancouver")

# %%
jsonFn2_van_stations = city_stations("Vancouver")

# %%
#Load the data into the DataFrame
df = station_data('Vancouver')

# Save a copy
df.to_csv(f'data/newdf_van_station_data{save_num_newdf}.csv', index=False)
save_num_newdf += 1

# %%
#lets check out the size of our new df!
df.shape
# Out:
# (241, 10)

# %%
# To display the top 5 rows and headers
df.head(5)
# Out:
#                        Station Name  slots  empty_slots  free_bikes  status  \
# 0                0001 10th & Cambie     35           13          22  online
# 1  0004 Yaletown-Roundhouse Station     16            8           8  online
# 2            0005 Dunsmuir & Beatty     26            5          21  online
# 3     0007 12th & Yukon (City Hall)     16           10           6  online
# 4                    0008 8th & Ash     16            7           9  online
#
#   bank_card   latitude   longitude                    timestamp Unique ID
# 0        No  49.262487 -123.114397  2022-11-05T23:37:09.287000Z      0001
# 1        No  49.274566 -123.121817  2022-11-05T23:37:09.297000Z      0004
# 2        No  49.279764 -123.110154  2022-11-05T23:37:09.300000Z      0005
# 3        No  49.260599 -123.113504  2022-11-05T23:37:09.301000Z      0007
# 4        No  49.264215 -123.117772  2022-11-05T23:37:09.312000Z      0008

# %%
# To display the last 5 rows
df.tail(5)
# Out:
#                Station Name  slots  empty_slots  free_bikes  status bank_card  \
# 236     0516 Heather & 29th     22           20           1  online        No
# 237   0041 Cardero & Robson     26            7          19  online        No
# 238  0352 Commercial & 20th     18           15           3  online        No
# 239     0196 Hornby & Drake     24           20           4  online        No
# 240      210 Burrard & 14th     18           10           8  online        No
#
#       latitude   longitude                    timestamp Unique ID
# 236  49.245535 -123.120496  2022-11-05T23:37:09.544000Z      0516
# 237  49.289255 -123.132677  2022-11-05T23:37:09.360000Z      0041
# 238  49.252656 -123.067965  2022-11-05T23:37:09.521000Z      0352
# 239  49.277527 -123.129464  2022-11-05T23:37:09.452000Z      0196
# 240  49.259469 -123.145718  2022-11-05T23:37:09.555000Z       210

# %%
# Checking the types of data
df.dtypes
# Out:
# Station Name     object
# slots             int64
# empty_slots       int64
# free_bikes        int64
# status           object
# bank_card        object
# latitude        float64
# longitude       float64
# timestamp        object
# Unique ID        object
# dtype: object

# %%
#or also/alternatively:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Station Name  241 non-null    object
#  1   slots         241 non-null    int64
#  2   empty_slots   241 non-null    int64
#  3   free_bikes    241 non-null    int64
#  4   status        241 non-null    object
#  5   bank_card     241 non-null    object
#  6   latitude      241 non-null    float64
#  7   longitude     241 non-null    float64
#  8   timestamp     241 non-null    object
#  9   Unique ID     241 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 19.0+ KB

# %% [markdown]
# ----
# #

# %%
#save a back up just incase we come to regret some of our changes:
df_backup = df.copy()
#confirm the save:
df_backup.head(5)
# Out:
#                        Station Name  slots  empty_slots  free_bikes  status  \
# 0                0001 10th & Cambie     35           13          22  online
# 1  0004 Yaletown-Roundhouse Station     16            8           8  online
# 2            0005 Dunsmuir & Beatty     26            5          21  online
# 3     0007 12th & Yukon (City Hall)     16           10           6  online
# 4                    0008 8th & Ash     16            7           9  online
#
#   bank_card   latitude   longitude                    timestamp Unique ID
# 0        No  49.262487 -123.114397  2022-11-05T23:37:09.287000Z      0001
# 1        No  49.274566 -123.121817  2022-11-05T23:37:09.297000Z      0004
# 2        No  49.279764 -123.110154  2022-11-05T23:37:09.300000Z      0005
# 3        No  49.260599 -123.113504  2022-11-05T23:37:09.301000Z      0007
# 4        No  49.264215 -123.117772  2022-11-05T23:37:09.312000Z      0008

# %%
#dropping irrelevant columns
# df = df.drop(['col_a', 'col_b', 'col_c_etc.'], axis=1)
#recheck headings:
# df.head(5)

#I dont know if I'm ready to do this yet, I'll check back again later:

# %%
#renaming the columns if needed
df = df.rename(columns = {'Station Name':'name', 'empty_slots': 'empty', 'free_bikes': 'available', 'slots':'slots', 'Unique ID': 'unique_id'})
df.head(5)
# Out:
#                                name  slots  empty  available  status  \
# 0                0001 10th & Cambie     35     13         22  online
# 1  0004 Yaletown-Roundhouse Station     16      8          8  online
# 2            0005 Dunsmuir & Beatty     26      5         21  online
# 3     0007 12th & Yukon (City Hall)     16     10          6  online
# 4                    0008 8th & Ash     16      7          9  online
#
#   bank_card   latitude   longitude                    timestamp unique_id
# 0        No  49.262487 -123.114397  2022-11-05T23:37:09.287000Z      0001
# 1        No  49.274566 -123.121817  2022-11-05T23:37:09.297000Z      0004
# 2        No  49.279764 -123.110154  2022-11-05T23:37:09.300000Z      0005
# 3        No  49.260599 -123.113504  2022-11-05T23:37:09.301000Z      0007
# 4        No  49.264215 -123.117772  2022-11-05T23:37:09.312000Z      0008

# %%
#checking for the presence and location of duplicate rows
duplicate_rows_df = df[df.duplicated()]
#and compare the difference in the DF shape:
print(df.shape)
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# (241, 10)
# number of duplicate rows:  (0, 10)

# %%
# # we don't appear to have any duplicate rows
# #I'll comment this code out for now just incase it's needed later

# #first a count of the total rows to compare to #of duplicate rows
# df.count()
# #then we drop, and recheck:
# df = df.drop_duplicates()
# df.head(5)

# %%
#
df.count()
# Out:
# name         241
# slots        241
# empty        241
# available    241
# status       241
# bank_card    241
# latitude     241
# longitude    241
# timestamp    241
# unique_id    241
# dtype: int64

# %%
#drop any missing or null values: pretty sure we dont have any, but just in case:
print(df.isnull().sum())
# Out:
# name         0
# slots        0
# empty        0
# available    0
# status       0
# bank_card    0
# latitude     0
# longitude    0
# timestamp    0
# unique_id    0
# dtype: int64

# %%
# #again, we dont have any, but the code will placehold for now:

# #we'll drop the full rows that contain null values:
# df = dfdropna()
# df.count()

# %%
# #validating the dropped missing values
# print(df.isnull().sum())

# %%
#detecting outliers on numerical values:
# recheck data types to find the columns to check
df.dtypes
# Out:
# name          object
# slots          int64
# empty          int64
# available      int64
# status        object
# bank_card     object
# latitude     float64
# longitude    float64
# timestamp     object
# unique_id     object
# dtype: object

# %%
#slot values are appropriate as integers
#status and bank cards are strings - I guess obj is same/okay?
#lat and long are floats, as they should be
#time stamp is an object, we could probably convert that to a date time item
# and id is an obj, which is good.  

#just the time then:

# %%
# Save a copy of our df with it's new changes:
df.to_csv(f'data/newdf_van_station_data{save_num_df}.csv', index=False)
save_num_df += 1

# %% [markdown]
# ----
# # Part 2

# %%
df.head(5)
# Out:
#                                name  slots  empty  available  status  \
# 0                0001 10th & Cambie     35     13         22  online
# 1  0004 Yaletown-Roundhouse Station     16      8          8  online
# 2            0005 Dunsmuir & Beatty     26      5         21  online
# 3     0007 12th & Yukon (City Hall)     16     10          6  online
# 4                    0008 8th & Ash     16      7          9  online
#
#   bank_card   latitude   longitude                    timestamp unique_id
# 0        No  49.262487 -123.114397  2022-11-05T23:37:09.287000Z      0001
# 1        No  49.274566 -123.121817  2022-11-05T23:37:09.297000Z      0004
# 2        No  49.279764 -123.110154  2022-11-05T23:37:09.300000Z      0005
# 3        No  49.260599 -123.113504  2022-11-05T23:37:09.301000Z      0007
# 4        No  49.264215 -123.117772  2022-11-05T23:37:09.312000Z      0008

# %% [markdown]
# ## API for data collection at the location points of each station

# %% [markdown]
# foursquare api:
# https://location.foursquare.com/developer/reference/place-search

# %%
#define a function to return a list of dictionaries with information about the requested city


import os


def station_loci(ll_value):
    ''' a function that takes string lat-long as '0.00,-0.00' as it's only argument, 
    and returns a DataFrame object with the following parameters
    '''
    api_key = os.environ["FOURSQUARE_API_KEY"]
    fsq_data_url = (f'https://api.foursquare.com/v3/places/search?ll={ll_value}&radius=1000&fields=rating')
    headers = {
        "accept": "application/json",             #Incorporate headers and API key
        "Authorization": api_key
    }
    fsq_loci_results = requests.get(fsq_data_url, headers=headers).json()           #Perform get request

    list_of_dict = []
    for poi in fsq_loci_results['results']:
        loci_poi_dict = {
              'lat-long': f'{ll_value}'
            , 'cat_id': poi['categories'][0]['id']
            , 'category_name': poi['categories'][0]['name']
            , 'name': poi['name']
            , 'distance': poi['distance']
            , 'latitude': poi['geocodes']['main']['latitude']
            , 'longitude': poi['geocodes']['main']['longitude']
            , 'formatted_address': poi['location']['formatted_address']
            # , 'link': poi['link']
            # , 'address': poi['location']['address']
            # , 'country': poi['location']['country']
            # , 'cross_street': poi['location']['cross_street']
            # , 'locality': poi['location']['locality']
            # , 'postcode': poi['location']['postcode']
            # , 'region': poi['location']['region']
            # , 'timezone': poi['timezone']
        }
        list_of_dict.append(loci_poi_dict)
    return pd.DataFrame(list_of_dict)

# %%
# ', '.join(info['extra']['bank_card']) if info['extra']['bank_card'] else 'No'

# %%
test_ll = station_loci('49.262487,-123.114397')
test_ll
# Out:
#                 lat-long  cat_id       category_name  \
# 0  49.262487,-123.114397   11009  Automotive Service
# 1  49.262487,-123.114397   13306     Taco Restaurant
# 2  49.262487,-123.114397   13199   Indian Restaurant
# 3  49.262487,-123.114397   13035         Coffee Shop
# 4  49.262487,-123.114397   13003                 Bar
# 5  49.262487,-123.114397   13035         Coffee Shop
# 6  49.262487,-123.114397   13064            Pizzeria
# 7  49.262487,-123.114397   13026           BBQ Joint
# 8  49.262487,-123.114397   13059           Juice Bar
# 9  49.262487,-123.114397   16032                Park
#
#                                 name  distance   latitude   longitude  \
# 0  Canadian Tire Auto Service Centre       291  49.265110 -123.114437
# 1       La Taqueria Pinche Taco Shop       164  49.263601 -123.112665
# 2                              Vij's       553  49.257634 -123.114751
# 3                      Milano Coffee       430  49.263703 -123.108618
# 4                33 Acres Brewing Co       674  49.263877 -123.105307
# 5                     Elysian Coffee       724  49.264587 -123.105043
# 6                    Corduroy Pie Co       782  49.256883 -123.121094
# 7                       Gyu-Kaku BBQ       813  49.263191 -123.125282
# 8                    The Juice Truck       779  49.266348 -123.105436
# 9                     Charleson Park       891  49.267058 -123.124558
#
#                                    formatted_address
# 0  2290 Cambie St (at W 7th Ave), Vancouver BC V5...
# 1  2450 Yukon St (at W Broadway), Vancouver BC V5...
# 2  3106 Cambie St (at W 15th Ave), Vancouver BC V...
# 3  156 8th Ave W (btwn Columbia & Manitoba St), V...
# 4  15 8th Ave W (btwn Manitoba & Ontario), Vancou...
# 5  2301 Ontario St (at 7th Ave), Vancouver BC V5T...
# 6      758 16th Ave W (Willow), Vancouver BC V5Z 1S7
# 7  950 Broadway W (at Laurel St), Vancouver BC V5...
# 8  28 5th Ave W (btwn Manitoba & Ontario), Vancou...
# 9                     999 Charleson St, Vancouver BC

# %%
test_ll.shape
# Out:
# (10, 8)

# %%
#make a df copy for the lat and long values in string format as needed for the fsq api query
ll_df = df.copy()
ll_df.head(5)
# Out:
#                                name  slots  empty  available  status  \
# 0                0001 10th & Cambie     35     13         22  online
# 1  0004 Yaletown-Roundhouse Station     16      8          8  online
# 2            0005 Dunsmuir & Beatty     26      5         21  online
# 3     0007 12th & Yukon (City Hall)     16     10          6  online
# 4                    0008 8th & Ash     16      7          9  online
#
#   bank_card   latitude   longitude                    timestamp unique_id
# 0        No  49.262487 -123.114397  2022-11-05T23:37:09.287000Z      0001
# 1        No  49.274566 -123.121817  2022-11-05T23:37:09.297000Z      0004
# 2        No  49.279764 -123.110154  2022-11-05T23:37:09.300000Z      0005
# 3        No  49.260599 -123.113504  2022-11-05T23:37:09.301000Z      0007
# 4        No  49.264215 -123.117772  2022-11-05T23:37:09.312000Z      0008

# %%
# create a new column with the coordinate data we need, reformated to str dtype.

#grab just the two columns we need lat and lon
ll_df.dropna(subset=['latitude', 'longitude'], inplace=True)

# creation of a new variable with lon and lat together, label the column header 'll'
ll_df['ll'] = ll_df['latitude'].astype(str) + ',' + ll_df['longitude'].astype(str)
ll_df = ll_df[ll_df['ll'] != '0.0,0.0']
print(ll_df.shape)
print(ll_df.dtypes)
ll_df.head()

# reference #from Data wrangling exercise
# Out:
# (241, 11)
# name          object
# slots          int64
# empty          int64
# available      int64
# status        object
# bank_card     object
# latitude     float64
# longitude    float64
# timestamp     object
# unique_id     object
# ll            object
# dtype: object
#                                name  slots  empty  available  status  \
# 0                0001 10th & Cambie     35     13         22  online
# 1  0004 Yaletown-Roundhouse Station     16      8          8  online
# 2            0005 Dunsmuir & Beatty     26      5         21  online
# 3     0007 12th & Yukon (City Hall)     16     10          6  online
# 4                    0008 8th & Ash     16      7          9  online
#
#   bank_card   latitude   longitude                    timestamp unique_id  \
# 0        No  49.262487 -123.114397  2022-11-05T23:37:09.287000Z      0001
# 1        No  49.274566 -123.121817  2022-11-05T23:37:09.297000Z      0004
# 2        No  49.279764 -123.110154  2022-11-05T23:37:09.300000Z      0005
# 3        No  49.260599 -123.113504  2022-11-05T23:37:09.301000Z      0007
# 4        No  49.264215 -123.117772  2022-11-05T23:37:09.312000Z      0008
#
#                       ll
# 0  49.262487,-123.114397
# 1  49.274566,-123.121817
# 2  49.279764,-123.110154
# 3  49.260599,-123.113504
# 4  49.264215,-123.117772

# %%
# create a series of ll:
ll = ll_df['ll']
ll.head(5)
# Out:
# 0      49.262487,-123.114397
# 1      49.274566,-123.121817
# 2      49.279764,-123.110154
# 3      49.260599,-123.113504
# 4      49.264215,-123.117772
#                ...
# 236    49.245535,-123.120496
# 237    49.289255,-123.132677
# 238    49.252656,-123.067965
# 239    49.277527,-123.129464
# 240    49.259469,-123.145718
# Name: ll, Length: 241, dtype: object

# %%
# populate an empty list with the pd.df objects from each ll location:
df_list = []
for loci in ll:
    next = station_loci(loci)
    df_list.append(next)

# %%
# refresh df objects to avoid duplication
df_fsq = pd.DataFrame()
x = pd.DataFrame()

# generate full df object with all locations through concatenation 
for df_loci in df_list:
    x = pd.concat([df_fsq, df_loci])
    df_fsq = x

# %%
#confirm success:
df_fsq.shape
# Out:
# (2410, 8)

# %%
#save the new df:
df_fsq.to_csv(f'data/df_fsq_all_loci{save_num_df_fsq}.csv', index=False)
save_num_df_fsq += 1

# %%
df_fsq.head(20)
# Out:
#                 lat-long  cat_id        category_name  \
# 0  49.262487,-123.114397   11009   Automotive Service
# 1  49.262487,-123.114397   13306      Taco Restaurant
# 2  49.262487,-123.114397   13199    Indian Restaurant
# 3  49.262487,-123.114397   13035          Coffee Shop
# 4  49.262487,-123.114397   13003                  Bar
# 5  49.262487,-123.114397   13035          Coffee Shop
# 6  49.262487,-123.114397   13064             Pizzeria
# 7  49.262487,-123.114397   13026            BBQ Joint
# 8  49.262487,-123.114397   13059            Juice Bar
# 9  49.262487,-123.114397   16032                 Park
# 0  49.274566,-123.121817   13276     Sushi Restaurant
# 1  49.274566,-123.121817   13046     Ice Cream Parlor
# 2  49.274566,-123.121817   17085     Housewares Store
# 3  49.274566,-123.121817   13338   Seafood Restaurant
# 4  49.274566,-123.121817   16032                 Park
# 5  49.274566,-123.121817   13068  American Restaurant
# 6  49.274566,-123.121817   13306      Taco Restaurant
# 7  49.274566,-123.121817   13002               Bakery
# 8  49.274566,-123.121817   13236   Italian Restaurant
# 9  49.274566,-123.121817   16053           Waterfront
#
#                                 name  distance   latitude   longitude  \
# 0  Canadian Tire Auto Service Centre       291  49.265110 -123.114437
# 1       La Taqueria Pinche Taco Shop       164  49.263601 -123.112665
# 2                              Vij's       553  49.257634 -123.114751
# 3                      Milano Coffee       430  49.263703 -123.108618
# 4                33 Acres Brewing Co       674  49.263877 -123.105307
# 5                     Elysian Coffee       724  49.264587 -123.105043
# 6                    Corduroy Pie Co       782  49.256883 -123.121094
# 7                       Gyu-Kaku BBQ       813  49.263191 -123.125282
# 8                    The Juice Truck       779  49.266348 -123.105436
# 9                     Charleson Park       891  49.267058 -123.124558
# 0                  Minami Restaurant       110  49.275212 -123.120792
# 1                             Mister        66  49.275114 -123.121514
# 2           The Cross Decor & Design       108  49.275202 -123.122982
# 3          Blue Water Cafe + Raw Bar       185  49.276123 -123.121114
# 4                     David Lam Park       276  49.272309 -123.124276
# 5            The Flying Pig Yaletown        83  49.275181 -123.122007
# 6                           Tacofino       272  49.276488 -123.119685
# 7               Small Victory Bakery       219  49.276370 -123.121216
# 8                        La Terrazza       222  49.274923 -123.118740
# 9                 Marinaside Seawall       241  49.272849 -123.119536
#
#                                    formatted_address
# 0  2290 Cambie St (at W 7th Ave), Vancouver BC V5...
# 1  2450 Yukon St (at W Broadway), Vancouver BC V5...
# 2  3106 Cambie St (at W 15th Ave), Vancouver BC V...
# 3  156 8th Ave W (btwn Columbia & Manitoba St), V...
# 4  15 8th Ave W (btwn Manitoba & Ontario), Vancou...
# 5  2301 Ontario St (at 7th Ave), Vancouver BC V5T...
# 6      758 16th Ave W (Willow), Vancouver BC V5Z 1S7
# 7  950 Broadway W (at Laurel St), Vancouver BC V5...
# 8  28 5th Ave W (btwn Manitoba & Ontario), Vancou...
# 9                     999 Charleson St, Vancouver BC
# 0  1118 Mainland St (at Helmcken St.), Vancouver ...
# 1  1141 Mainland St (btwn Davie & Helmcken), Vanc...
# 2  1198 Homer St (at Davie St), Vancouver BC V6B 2X6
# 3  1095 Hamilton St (at Helmcken St), Vancouver B...
# 4            1300 Pacific Blvd, Vancouver BC V6Z 0A9
# 5  1168 Hamilton St (btwn Davie & Helmcken St), V...
# 6    1025 Mainland St (Nelson), Vancouver BC V6B 5P9
# 7  1088 Homer St (btwn Helmcken & Nelson), Vancou...
# 8  1088 Cambie St (at Pacific Blvd.), Vancouver B...
# 9  1177 Marinaside Cres (at Davie St), Vancouver ...

# %% [markdown]
# ----
# > **Personal NOTE:** I think marty was helping me while I was in the bathroom... but I dont know what these are for.   saving them as a note in this markdown cell for now lol
# ```py
# def make_get_request(api_key, url):
#     headers = {
#         "accept": "application/json",
#         "Authorization": api_key
#     }
#
#     return requests.get(url, headers=headers).json()
#
# def make_fsq_request(url):
#     api_key = os.environ["FOURSQUARE_API_KEY"]
#     base_url = (f'https://api.foursquare.com/v3/places')
#     return make_get_request(api_key, base_url)
#
# def make_yelp_request(ll_value):
#     api_key = os.environ["FOURSQUARE_API_KEY"]
#     base_url = (f'https://api.foursquare.com/v3/places/search?ll={ll_value}')
#     return make_get_request(api_key, base_url)
# ```
# ----

# %% [markdown]
# #### Yelp
# Yelp api = https://api.yelp.com/v3/businesses/search?latitude=49.262487&longitude=-123.114397&radius=1000

# %%
#define a function to return a list of dictionaries with information about the requested city

import requests
import os


def station_loci(lat, long):
    ''' a funtion that takes string lat and long as '0.00', and '-0.00' as it's arguments, 
    and returns a DataFrame object with the following parameters
    '''
    api_key = os.environ["YELP_API_KEY"]
    yelp_data_url = (f'https://api.yelp.com/v3/businesses/search?latitude={lat}&longitude={long}&radius=1000')
    payload={}
    headers = {
        'accept': 'application/json',             #Incorporate headers and API key
        'Authorization': f'Bearer {api_key}'
    }
    yelp_loci_results = requests.get(yelp_data_url, headers=headers, data=payload).json()           #Perform get request

    list_of_dict = []
    for poi in yelp_loci_results["businesses"]:
        loci_poi_dict = {
              'lat-long': f'{lat}, {long}'
            # , 'cat_id': poi['categories'][0]['id']
            , 'category_name': poi['categories'][0]['title'] #', '.join(poi['categories'][1]['title']) if poi['categories'][1]['title'] else 'No'
            , 'categories': poi['categories']
            , 'name': poi['name']
            , 'distance': poi['distance']
            , 'latitude': poi['coordinates']['latitude']
            , 'longitude': poi['coordinates']['longitude']
            , 'address': poi['location']['display_address']
            , 'is_closed': poi['is_closed']
            # , 'display_phone': poi['location']['display_phone']
            , 'review_count': poi['review_count']
            , 'rating': poi['rating']
            # , 'address1': poi['location']['address1']
            # , 'city': poi['location']['city']
            # , 'zip_code': poi['location']['zip_code']
            # , 'country': poi['location']['country']
            # , 'state': poi['location']['state']
        }
        list_of_dict.append(loci_poi_dict)
    return pd.DataFrame(list_of_dict)

# %%
# a test run of the function
yelp_test_ll = station_loci('49.262487','-123.114397')
yelp_test_ll
# Out:
#                   lat-long              category_name  \
# 0   49.262487, -123.114397                    Mexican
# 1   49.262487, -123.114397                    Chinese
# 2   49.262487, -123.114397                      Cafes
# 3   49.262487, -123.114397                    Noodles
# 4   49.262487, -123.114397                   Japanese
# 5   49.262487, -123.114397                     Indian
# 6   49.262487, -123.114397               Coffee & Tea
# 7   49.262487, -123.114397                   Desserts
# 8   49.262487, -123.114397                     Indian
# 9   49.262487, -123.114397                   Japanese
# 10  49.262487, -123.114397                   Japanese
# 11  49.262487, -123.114397  Ice Cream & Frozen Yogurt
# 12  49.262487, -123.114397                      Cafes
# 13  49.262487, -123.114397                   Japanese
# 14  49.262487, -123.114397                   Desserts
# 15  49.262487, -123.114397                 Sushi Bars
# 16  49.262487, -123.114397               Coffee & Tea
# 17  49.262487, -123.114397               Coffee & Tea
# 18  49.262487, -123.114397                   Hawaiian
# 19  49.262487, -123.114397               Coffee & Tea
#
#                             name     distance   latitude   longitude  \
# 0   La Taqueria Pinche Taco Shop   169.517456  49.263559 -123.112736
# 1            Peaceful Restaurant   146.418009  49.263147 -123.116143
# 2                  Marulilu Cafe   102.329817  49.263380 -123.114150
# 3        Hokkaido Ramen Santouka   191.044234  49.263127 -123.116892
# 4                           Saku   176.444610  49.263125 -123.116603
# 5               Vij's Restaurant   547.596751  49.257540 -123.114790
# 6                          Yolks   170.324037  49.263114 -123.116353
# 7          Passion8 Dessert Cafe   452.638601  49.258435 -123.114998
# 8            Indian Roti Kitchen   391.283162  49.259010 -123.115380
# 9                      Uma Sushi   152.157897  49.263805 -123.113729
# 10                         Shiro   506.999733  49.258004 -123.114915
# 11             Earnest Ice Cream  1093.727955  49.268863 -123.102919
# 12          49th Parallel Coffee  1049.076361  49.259133 -123.100885
# 13              Sushi California   143.492170  49.263045 -123.112614
# 14       Rain or Shine Ice Cream   821.367629  49.255146 -123.114929
# 15                   Toshi Sushi  1109.932618  49.256699 -123.101936
# 16           Aperture Coffee Bar   295.924920  49.263204 -123.110470
# 17                Elysian Coffee   221.080646  49.262940 -123.117280
# 18                Westcoast Poke   182.239951  49.264090 -123.114041
# 19              Caffe Cittadella   331.734686  49.264809 -123.117267
#
#                                               address  is_closed  \
# 0   [2450 Yukon Street, Vancouver, BC V5Z 3V6, Can...      False
# 1   [110-532 W Broadway, Vancouver, BC V5Z 1E9, Ca...      False
# 2     [451 W Broadway, Vancouver, BC V5Y 1R4, Canada]      False
# 3     [558 W Broadway, Vancouver, BC V5Z 1E9, Canada]      False
# 4     [548 W Broadway, Vancouver, BC V5Z 1E9, Canada]      False
# 5   [3106 Cambie Street, Vancouver, BC V5Z 2W2, Ca...      False
# 6     [546 W Broadway, Vancouver, BC V5Z 1E9, Canada]      False
# 7   [3010 Cambie Street, Vancouver, BC V5Z 2V9, Ca...      False
# 8   [2961 Cambie Street, Vancouver, BC V5Z 2V7, Ca...      False
# 9   [450 W 8th Avenue, Vancouver, BC V5Y 1N9, Canada]      False
# 10  [3096 Cambie Street, Vancouver, BC V5Z 2V9, Ca...      False
# 11  [1829 Quebec Street, Vancouver, BC V5T 2Z3, Ca...      False
# 12  [2902 Main Street, Vancouver, BC V5T 0C1, Canada]      False
# 13    [388 W Broadway, Vancouver, BC V5Y 4A8, Canada]      False
# 14  [3382 Cambie Street, Vancouver, BC V5Z 3K7, Ca...      False
# 15  [181 East 16th Avenue, Vancouver, BC V5T 4R2, ...      False
# 16    [243 W Broadway, Vancouver, BC V5Y 3L1, Canada]      False
# 17    [590 W Broadway, Vancouver, BC V5Z 1E9, Canada]      False
# 18  [463 W 8th Avenue, Vancouver, BC V5Y 3Z5, Canada]      False
# 19   [2310 Ash Street, Vancouver, BC V5Z 3C2, Canada]      False
#
#     review_count  rating
# 0            667     4.0
# 1            610     3.5
# 2            281     4.0
# 3            218     4.0
# 4            182     4.0
# 5            366     4.0
# 6            336     3.5
# 7            201     4.0
# 8            153     4.5
# 9            109     4.5
# 10           240     4.0
# 11           367     4.5
# 12           496     4.0
# 13           310     3.5
# 14           233     4.5
# 15           430     4.0
# 16           122     4.0
# 17           207     3.5
# 18           170     4.0
# 19           152     4.0

# %%
#to run location queries, we'll need the lat and log values for each station to be accessable:

# create a series of latitude:
lat = df['latitude']
print(lat.head(5))
# create a series of longitude:
long = df['longitude']
print(long.head(5))
type(long)

# Save the new series
lat.to_csv(f'data/lat_series{save_num_lat}.csv', index=False)
long.to_csv(f'data/long_series{save_num_long}.csv', index=False)
save_num_lat += 1
save_num_long += 1
# Out:
# 0    49.262487
# 1    49.274566
# 2    49.279764
# 3    49.260599
# 4    49.264215
# Name: latitude, dtype: float64
# 0   -123.114397
# 1   -123.121817
# 2   -123.110154
# 3   -123.113504
# 4   -123.117772
# Name: longitude, dtype: float64

# %%
# create a while loop to run the series lat and long through the yelp api function
# This will generate a list of 241 df; one for each of the citybike.s stations

num_rows = df.shape[0]
row_counter = 0
yelp_df_list = []
while row_counter < num_rows:
    next = station_loci(lat[row_counter], long[row_counter])
    yelp_df_list.append(next)
    row_counter += 1

# %%
# refresh df objects to avoid duplication
df_yelp = pd.DataFrame()
x = pd.DataFrame()

# generate full df object with all locations through concatenation 
for df_loci in yelp_df_list:
    x = pd.concat([df_yelp, df_loci])
    df_yelp = x

# %%
#confirm success:
df_yelp.shape
# Out:
# (4788, 10)

# %%
# save new df
df_yelp.to_csv(f'data/newdf_yelp_all_loci{save_num_df_yelp}.csv', index=False)
save_num_df_yelp += 1

# %%
df_yelp.head(50)
# Out:
#                   lat-long              category_name  \
# 0   49.262487, -123.114397                    Mexican
# 1   49.262487, -123.114397                    Chinese
# 2   49.262487, -123.114397                      Cafes
# 3   49.262487, -123.114397                    Noodles
# 4   49.262487, -123.114397                   Japanese
# 5   49.262487, -123.114397                     Indian
# 6   49.262487, -123.114397               Coffee & Tea
# 7   49.262487, -123.114397                   Desserts
# 8   49.262487, -123.114397                     Indian
# 9   49.262487, -123.114397                   Japanese
# 10  49.262487, -123.114397                   Japanese
# 11  49.262487, -123.114397  Ice Cream & Frozen Yogurt
# 12  49.262487, -123.114397                      Cafes
# 13  49.262487, -123.114397                   Japanese
# 14  49.262487, -123.114397                   Desserts
# 15  49.262487, -123.114397                 Sushi Bars
# 16  49.262487, -123.114397               Coffee & Tea
# 17  49.262487, -123.114397               Coffee & Tea
# 18  49.262487, -123.114397                   Hawaiian
# 19  49.262487, -123.114397               Coffee & Tea
# 0   49.274566, -123.121817                    Seafood
# 1   49.274566, -123.121817             Canadian (New)
# 2   49.274566, -123.121817         Breakfast & Brunch
# 3   49.274566, -123.121817                   Japanese
# 4   49.274566, -123.121817                    Seafood
# 5   49.274566, -123.121817         Breakfast & Brunch
# 6   49.274566, -123.121817                  Fast Food
# 7   49.274566, -123.121817                    Italian
# 8   49.274566, -123.121817              Mediterranean
# 9   49.274566, -123.121817                    Waffles
# 10  49.274566, -123.121817         Breakfast & Brunch
# 11  49.274566, -123.121817                    Seafood
# 12  49.274566, -123.121817                    Belgian
# 13  49.274566, -123.121817                    Italian
# 14  49.274566, -123.121817               Coffee & Tea
# 15  49.274566, -123.121817                    Mexican
# 16  49.274566, -123.121817                  Wine Bars
# 17  49.274566, -123.121817                   Hot Dogs
# 18  49.274566, -123.121817                   Japanese
# 19  49.274566, -123.121817              Mediterranean
# 0   49.279764, -123.110154         Breakfast & Brunch
# 1   49.279764, -123.110154                    Belgian
# 2   49.279764, -123.110154         Breakfast & Brunch
# 3   49.279764, -123.110154                   Japanese
# 4   49.279764, -123.110154                    Seafood
# 5   49.279764, -123.110154                 Sandwiches
# 6   49.279764, -123.110154               Coffee & Tea
# 7   49.279764, -123.110154                     French
# 8   49.279764, -123.110154                   Bakeries
# 9   49.279764, -123.110154                    Mexican
#
#                                        name     distance   latitude  \
# 0              La Taqueria Pinche Taco Shop   169.517456  49.263559
# 1                       Peaceful Restaurant   146.418009  49.263147
# 2                             Marulilu Cafe   102.329817  49.263380
# 3                   Hokkaido Ramen Santouka   191.044234  49.263127
# 4                                      Saku   176.444610  49.263125
# 5                          Vij's Restaurant   547.596751  49.257540
# 6                                     Yolks   170.324037  49.263114
# 7                     Passion8 Dessert Cafe   452.638601  49.258435
# 8                       Indian Roti Kitchen   391.283162  49.259010
# 9                                 Uma Sushi   152.157897  49.263805
# 10                                    Shiro   506.999733  49.258004
# 11                        Earnest Ice Cream  1093.727955  49.268863
# 12                     49th Parallel Coffee  1049.076361  49.259133
# 13                         Sushi California   143.492170  49.263045
# 14                  Rain or Shine Ice Cream   821.367629  49.255146
# 15                              Toshi Sushi  1109.932618  49.256699
# 16                      Aperture Coffee Bar   295.924920  49.263204
# 17                           Elysian Coffee   221.080646  49.262940
# 18                           Westcoast Poke   182.239951  49.264090
# 19                         Caffe Cittadella   331.734686  49.264809
# 0                           Blue Water Cafe   190.502213  49.276195
# 1                            The Flying Pig    54.990917  49.275010
# 2                               Medina Cafe   739.815859  49.280443
# 3                                    Minami   106.404291  49.275273
# 4                     Rodney's Oyster House   104.884148  49.274433
# 5                OEB Breakfast Co. Yaletown   222.481980  49.273434
# 6                  Fritz European Fry House   465.329891  49.277205
# 7                            Robba da Matti   108.898789  49.275340
# 8                                Manoush'eh   366.277991  49.276671
# 9                              Nero Waffles   420.421911  49.278344
# 10                       Jam Cafe on Beatty  1085.617526  49.280259
# 11  Fanny Bay Oyster Bar & Shellfish Market   717.579172  49.278753
# 12                                  Chambar  1062.620769  49.280146
# 13                                     Lupo   517.428879  49.278230
# 14                     Small Victory Bakery   217.441468  49.276480
# 15          The Mexican Antojitos Y Cantina   495.936952  49.278773
# 16                            Brix & Mortar   116.932936  49.275616
# 17                                  Japadog   680.512145  49.280267
# 18                                Shizen Ya   731.563826  49.280884
# 19           Cioppino's Mediterranean Grill   106.315327  49.275522
# 0                        Jam Cafe on Beatty    65.350935  49.280259
# 1                                   Chambar    45.600507  49.280146
# 2                               Medina Cafe   504.911371  49.280443
# 3                                      Miku   817.639764  49.286918
# 4   Fanny Bay Oyster Bar & Shellfish Market   314.176953  49.278753
# 5                              Meat & Bread   323.658335  49.282626
# 6                                  Revolver   384.450834  49.283273
# 7                              Twisted Fork   562.988187  49.283194
# 8                                 Purebread   308.780303  49.282467
# 9              La Taqueria Pinche Taco Shop   351.486708  49.282912
#
#      longitude                                            address  is_closed  \
# 0  -123.112736  [2450 Yukon Street, Vancouver, BC V5Z 3V6, Can...      False
# 1  -123.116143  [110-532 W Broadway, Vancouver, BC V5Z 1E9, Ca...      False
# 2  -123.114150    [451 W Broadway, Vancouver, BC V5Y 1R4, Canada]      False
# 3  -123.116892    [558 W Broadway, Vancouver, BC V5Z 1E9, Canada]      False
# 4  -123.116603    [548 W Broadway, Vancouver, BC V5Z 1E9, Canada]      False
# 5  -123.114790  [3106 Cambie Street, Vancouver, BC V5Z 2W2, Ca...      False
# 6  -123.116353    [546 W Broadway, Vancouver, BC V5Z 1E9, Canada]      False
# 7  -123.114998  [3010 Cambie Street, Vancouver, BC V5Z 2V9, Ca...      False
# 8  -123.115380  [2961 Cambie Street, Vancouver, BC V5Z 2V7, Ca...      False
# 9  -123.113729  [450 W 8th Avenue, Vancouver, BC V5Y 1N9, Canada]      False
# 10 -123.114915  [3096 Cambie Street, Vancouver, BC V5Z 2V9, Ca...      False
# 11 -123.102919  [1829 Quebec Street, Vancouver, BC V5T 2Z3, Ca...      False
# 12 -123.100885  [2902 Main Street, Vancouver, BC V5T 0C1, Canada]      False
# 13 -123.112614    [388 W Broadway, Vancouver, BC V5Y 4A8, Canada]      False
# 14 -123.114929  [3382 Cambie Street, Vancouver, BC V5Z 3K7, Ca...      False
# 15 -123.101936  [181 East 16th Avenue, Vancouver, BC V5T 4R2, ...      False
# 16 -123.110470    [243 W Broadway, Vancouver, BC V5Y 3L1, Canada]      False
# 17 -123.117280    [590 W Broadway, Vancouver, BC V5Z 1E9, Canada]      False
# 18 -123.114041  [463 W 8th Avenue, Vancouver, BC V5Y 3Z5, Canada]      False
# 19 -123.117267   [2310 Ash Street, Vancouver, BC V5Z 3C2, Canada]      False
# 0  -123.120993  [1095 Hamilton St, Vancouver, BC V6B 5T4, Canada]      False
# 1  -123.122000  [1168 Hamilton Street, Unit 104, Vancouver, BC...      False
# 2  -123.117036  [780 Richards Street, Vancouver, BC V6B 3A4, C...      False
# 3  -123.120703  [1118 Mainland Street, Vancouver, BC V6B 2T9, ...      False
# 4  -123.123248  [1228 Hamilton Street, Vancouver, BC V6B 6L2, ...      False
# 5  -123.119272  [1137 Marinaside Crescent, Vancouver, BC V6Z 2...      False
# 6  -123.126525  [718 Davie Street, Vancouver, BC V6Z 1B6, Canada]      False
# 7  -123.120897  [1127 Mainland Street, Vancouver, BC V6B 5P2, ...      False
# 8  -123.125701  [620 Davie Street, Vancouver, BC V6B 2G5, Canada]      False
# 9  -123.122045  [1002 Seymour Street, Vancouver, BC V6B 3M6, C...      False
# 10 -123.109638  [556 Beatty Street, Vancouver, BC V6B 2L3, Can...      False
# 11 -123.113869     [762 Cambie St, Vancouver, BC V6B 2P2, Canada]      False
# 12 -123.109925  [568 Beatty Street, Vancouver, BC V6B 2L3, Can...      False
# 13 -123.117400  [869 Hamilton Street, Vancouver, BC V6B 2R7, C...      False
# 14 -123.121205  [1088 Homer Street, Vancouver, BC V6B 2W9, Can...      False
# 15 -123.124027  [1049 Granville Street, Vancouver, BC V6Z 1L4,...      False
# 16 -123.121898  [1138 Homer Street, Vancouver, BC V6B 2X6, Can...      False
# 17 -123.118405  [530 Robson Street, Vancouver, BC V6B 2B7, Can...      False
# 18 -123.124628  [965 Hornby Street, Vancouver, BC V6Z 1V3, Can...      False
# 19 -123.121794  [1133 Hamilton Street, Vancouver, BC V6B 5P6, ...      False
# 0  -123.109638  [556 Beatty Street, Vancouver, BC V6B 2L3, Can...      False
# 1  -123.109925  [568 Beatty Street, Vancouver, BC V6B 2L3, Can...      False
# 2  -123.117036  [780 Richards Street, Vancouver, BC V6B 3A4, C...      False
# 3  -123.112763  [200 Granville Street, Suite 70, Vancouver, BC...      False
# 4  -123.113869     [762 Cambie St, Vancouver, BC V6B 2P2, Canada]      False
# 5  -123.109337  [370 Cambie Street, Vancouver, BC V6B 1H7, Can...      False
# 6  -123.109428  [325 Cambie Street, Vancouver, BC V6B 1H7, Can...      False
# 7  -123.104445  [213 Carral Street, Vancouver, BC V6B 2J2, Can...      False
# 8  -123.109180  [159 W Hastings Street, Vancouver, BC V6B 1H5,...      False
# 9  -123.110593  [322 W Hastings Street, Vancouver, BC V8B 1K6,...      False
#
#     review_count  rating
# 0            667     4.0
# 1            610     3.5
# 2            281     4.0
# 3            218     4.0
# 4            182     4.0
# 5            366     4.0
# 6            336     3.5
# 7            201     4.0
# 8            153     4.5
# 9            109     4.5
# 10           240     4.0
# 11           367     4.5
# 12           496     4.0
# 13           310     3.5
# 14           233     4.5
# 15           430     4.0
# 16           122     4.0
# 17           207     3.5
# 18           170     4.0
# 19           152     4.0
# 0           1015     4.5
# 1           1228     4.0
# 2           2503     4.0
# 3            724     4.0
# 4            782     4.0
# 5            629     4.5
# 6            774     4.0
# 7            469     4.0
# 8            220     5.0
# 9            445     4.5
# 10          1265     4.5
# 11           679     4.5
# 12          1493     4.0
# 13           426     4.5
# 14           295     4.0
# 15           387     4.5
# 16           311     4.0
# 17           785     4.0
# 18           575     4.0
# 19           183     4.5
# 0           1265     4.5
# 1           1493     4.0
# 2           2503     4.0
# 3           2051     4.5
# 4            679     4.5
# 5            777     4.0
# 6            572     4.5
# 7           1084     4.0
# 8            405     4.5
# 9            505     4.5

# %%
df_yelp.query('category_name == "restaurant"')
# Out:
# Empty DataFrame
# Columns: [lat-long, category_name, name, distance, latitude, longitude, address, is_closed, review_count, rating]
# Index: []

# %%
#save data to file
df.to_csv(f'data/station_data_sample{save_num_df}.csv', index=False)
save_num_df += 1
df_fsq.to_csv(f'data/foursq_df_all_stations{save_num_df_fsq}.csv', index=False)
save_num_df_fsq += 1
ll.to_csv(f'data/lat_long_series{save_num_ll}.csv', index=False)
save_num_ll += 1
